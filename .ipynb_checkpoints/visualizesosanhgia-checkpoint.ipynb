# %%
import pandas as pd
import matplotlib.pyplot as plt     
import matplotlib.ticker as ticker
import numpy as np

# %% [markdown]
# ## Đọc dữ liệu từ file csv

# %%
df = pd.read_csv("sosanhgia.csv")

# %% [markdown]
# ## Hiển thị dữ liệu

# %%
df
# Out:
#       Unnamed: 0                                               link  \
# 0              0  https://www.sosanhgia.com/p186133-laptop-hp-pa...
# 1              1  https://www.sosanhgia.com/p2884-macbook-air-md...
# 2              2  https://www.sosanhgia.com/p5498-macbook-pro-mf...
# 3              3  https://www.sosanhgia.com/p39528-macbook-air-m...
# 4              4  https://www.sosanhgia.com/p167163-mang-boc-thu...
# ...          ...                                                ...
# 2809        2809  https://www.sosanhgia.com/p7434-may-chieu-epso...
# 2810        2810  https://www.sosanhgia.com/p22608-man-hinh-asus...
# 2811        2811  https://www.sosanhgia.com/p206847-dau-me-beksu...
# 2812        2812  https://www.sosanhgia.com/p30270-muc-in-brothe...
# 2813        2813  https://www.sosanhgia.com/p108947-dia-thuy-tin...
#
#                                                category  \
# 0     ['Máy tính - Thiết bị VP', 'Laptop', 'Laptop HP']
# 1       ['Máy tính - Thiết bị VP', 'Laptop', 'Macbook']
# 2       ['Máy tính - Thiết bị VP', 'Laptop', 'Macbook']
# 3       ['Máy tính - Thiết bị VP', 'Laptop', 'Macbook']
# 4     ['Nhà cửa đời sống', 'Vật dụng nhà bếp - Phòng...
# ...                                                 ...
# 2809  ['Máy tính - Thiết bị VP', 'Thiết bị VP', 'Máy...
# 2810  ['Máy tính - Thiết bị VP', 'Màn hình máy tính'...
# 2811          ['Thực phẩm', 'Dầu ăn', 'Dầu ăn  Beksul']
# 2812  ['Máy tính - Thiết bị VP', 'Thiết bị VP', 'Mực...
# 2813  ['Nhà cửa đời sống', 'Vật dụng nhà bếp - Phòng...
#
#                                                    name  \
# 0                Laptop HP Pavilion 15-CS3060TX 8RJ61PA
# 1                            Macbook AIR MD711 11.6inch
# 2                                Macbook Pro MF839 2015
# 3                                     Macbook Air MC965
# 4                        Màng bọc thực phẩm Ringo ST618
# ...                                                 ...
# 2809                             Máy chiếu Epson EB-X03
# 2810                        Màn Hình Asus PB298Q 29inch
# 2811                                DẦU MÈ BEKSUL 500ML
# 2812  Mực in Brother LC-37BK Dùng cho máy DCP-135C,1...
# 2813              Đĩa Thủy Tinh Diva Ivory La Opala 270
#
#                                                 img_url    brand  \
# 0     https://img.sosanhgia.com/images/500x0/b54bfba...       HP
# 1     https://img.sosanhgia.com/images/500x0/10e76ab...    Apple
# 2     https://img.sosanhgia.com/images/500x0/53d11ee...    Apple
# 3     https://img.sosanhgia.com/images/500x0/b674cc0...    Apple
# 4     https://img.sosanhgia.com/images/500x0/a128e6b...     KHÁC
# ...                                                 ...      ...
# 2809  https://img.sosanhgia.com/images/500x0/b2710ad...    Epson
# 2810  https://img.sosanhgia.com/images/500x0/63889f5...     Asus
# 2811  https://img.sosanhgia.com/images/500x0/fbff8f5...   Beksul
# 2812  https://img.sosanhgia.com/images/500x0/88145f9...  Brother
# 2813  https://img.sosanhgia.com/images/500x0/e813aae...     KHÁC
#
#                                              short_desc priority_price  \
# 0     Bộ VXL: Core i5 1035G1 1.0Ghz-6Mb\n - Cạc đồ ...     17.100.000
# 1                                                   NaN      9.900.000
# 2     CPU: Core i5 5257U\n\nRAM/ HDD: 8Gb/ 128Gb SSD...     23.978.740
# 3     Độ lớn màn hình (inch) 13.3 inch\n Độ phân giả...     16.142.399
# 4     - Sản phẩm không chứa DEHA , DEHP độc hại\n - ...        357.000
# ...                                                 ...            ...
# 2809  Cường độ sáng: 2,700 Ansi Lumens\n\nĐộ phân gi...      9.459.000
# 2810  Kích thước: 29 inch\n Độ phân giải: 2560 x 108...      5.999.000
# 2811                                                NaN        259.000
# 2812  Màu mực: đen\n Số trang in 350 trang\n Bền màu...        330.000
# 2813   được điểm xuyết họa tiết 3D với một nhánh lá ...        263.000
#
#      priority_store  num_of_product  num_of_store lowest_price highest_price
# 0            Shopee            19.0          14.0   16.790.000    18.290.000
# 1            Lazada             5.0           3.0    9.900.000    12.183.024
# 2              Fado             4.0           2.0   18.572.680    19.550.202
# 3              Fado             NaN           NaN          NaN           NaN
# 4              Tiki             NaN           NaN          NaN           NaN
# ...             ...             ...           ...          ...           ...
# 2809         Lazada             NaN           NaN          NaN           NaN
# 2810  HanoiComputer             NaN           NaN          NaN           NaN
# 2811         Lazada             2.0           2.0      259.000       358.800
# 2812           Tiki             2.0           2.0      330.000       355.000
# 2813           Tiki             1.0           1.0      340.000             0
#
# [2814 rows x 13 columns]

# %% [markdown]
# ## Thống kê cơ bản về dữ liệu

# %%
df.describe()
# Out:
#         Unnamed: 0  num_of_product  num_of_store
# count  2814.000000     1983.000000   1983.000000
# mean   1406.500000        6.895613      8.240545
# std     812.476153        5.738297     32.586656
# min       0.000000        1.000000      1.000000
# 25%     703.250000        3.000000      3.000000
# 50%    1406.500000        5.000000      4.000000
# 75%    2109.750000        9.000000      5.000000
# max    2813.000000       42.000000    597.000000

# %% [markdown]
# ## Thống kê số brand của sản phẩm

# %%
df['brand'].value_counts()
# Out:
# Nhiều Tác Giả            1089
# KHÁC                      444
# Zento                      25
# Napoleon Hill              23
# X-Men                      15
#                          ...
# Thích Giác Viên             1
# Clare Mackintosh            1
# Nguyễn Hoàng Thanh Ly       1
# Minh Nhựt                   1
# Robert T. Kiyosaki          1
# Name: brand, Length: 490, dtype: int64

# %% [markdown]
# ## Lấy những sản phẩm có brand là Apple

# %%
brands = df.groupby('brand')

# %%
apple_brand = brands.get_group('Apple')
apple_brand
# Out:
#    Unnamed: 0                                               link  \
# 1           1  https://www.sosanhgia.com/p2884-macbook-air-md...
# 2           2  https://www.sosanhgia.com/p5498-macbook-pro-mf...
# 3           3  https://www.sosanhgia.com/p39528-macbook-air-m...
# 5           5  https://www.sosanhgia.com/p37449-macbook-pro-m...
# 7           7  https://www.sosanhgia.com/p37455-macbook-pro-m...
#
#                                           category  \
# 1  ['Máy tính - Thiết bị VP', 'Laptop', 'Macbook']
# 2  ['Máy tính - Thiết bị VP', 'Laptop', 'Macbook']
# 3  ['Máy tính - Thiết bị VP', 'Laptop', 'Macbook']
# 5  ['Máy tính - Thiết bị VP', 'Laptop', 'Macbook']
# 7  ['Máy tính - Thiết bị VP', 'Laptop', 'Macbook']
#
#                          name  \
# 1  Macbook AIR MD711 11.6inch
# 2      Macbook Pro MF839 2015
# 3           Macbook Air MC965
# 5  Macbook pro MD102 13.3inch
# 7  Macbook pro ME662 13.3inch
#
#                                              img_url  brand  \
# 1  https://img.sosanhgia.com/images/500x0/10e76ab...  Apple
# 2  https://img.sosanhgia.com/images/500x0/53d11ee...  Apple
# 3  https://img.sosanhgia.com/images/500x0/b674cc0...  Apple
# 5  https://img.sosanhgia.com/images/500x0/f4b11a4...  Apple
# 7  https://img.sosanhgia.com/images/500x0/0aa27ea...  Apple
#
#                                           short_desc priority_price  \
# 1                                                NaN      9.900.000
# 2  CPU: Core i5 5257U\n\nRAM/ HDD: 8Gb/ 128Gb SSD...     23.978.740
# 3  Độ lớn màn hình (inch) 13.3 inch\n Độ phân giả...     16.142.399
# 5  Hệ điều hành: Mac OS Leopard OX 10.5\n\nBộ vi ...     20.886.797
# 7  Hệ điều hành: Mac OS X Mountain Lion\n Bộ vi x...     19.574.044
#
#   priority_store  num_of_product  num_of_store lowest_price highest_price
# 1         Lazada             5.0           3.0    9.900.000    12.183.024
# 2           Fado             4.0           2.0   18.572.680    19.550.202
# 3           Fado             NaN           NaN          NaN           NaN
# 5           Fado             3.0           2.0   15.163.035    16.186.811
# 7     US Express             NaN           NaN          NaN           NaN

# %% [markdown]
# ## Vẽ biểu đồ tần suất của các trang thương mại điện tử

# %%
amount_ecommercesite = df['priority_store'].value_counts()

# %%
plt.subplots(figsize=(40,20))
plt.bar(amount_ecommercesite.index, amount_ecommercesite.values)
plt.xlabel('E-commerce site')
plt.ylabel('Erequency')
plt.show()
