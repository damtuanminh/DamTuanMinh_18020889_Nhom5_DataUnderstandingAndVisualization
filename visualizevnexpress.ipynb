# %%
import pandas as pd
import matplotlib.pyplot as plt     #I am pretty sure pyplot is the original functionality of matplotlib
import matplotlib.ticker as ticker
import numpy as np

# %% [markdown]
# ## Đọc dữ liệu từ file csv

# %%
df = pd.read_csv("vnexpress.csv")

# %% [markdown]
# ## Thống kê cơ bản về dữ liệu

# %%
df.describe()
# Out:
#        Unnamed: 0      pub_date
# count  112.000000  1.120000e+02
# mean    55.500000  1.590625e+09
# std     32.475632  1.448230e+07
# min      0.000000  1.504976e+09
# 25%     27.750000  1.594624e+09
# 50%     55.500000  1.596118e+09
# 75%     83.250000  1.596428e+09
# max    111.000000  1.596512e+09

# %% [markdown]
# ## Hiển thị dữ liệu

# %%
df
# Out:
#      Unnamed: 0                                               link  \
# 0             0  https://vnexpress.net/quang-ngai-co-tan-bi-thu...
# 1             1  https://vnexpress.net/them-7-nguoi-da-nang-3-q...
# 2             2  https://vnexpress.net/benh-nhan-covid-19-thu-7...
# 3             3  https://vnexpress.net/cuu-vua-tay-ban-nha-song...
# 4             4  https://vnexpress.net/container-tong-xe-5-cho-...
# ..          ...                                                ...
# 107         107  https://vnexpress.net/hong-kong-de-nghi-bac-ki...
# 108         108  https://vnexpress.net/chu-tich-cong-ty-dia-oc-...
# 109         109  https://vnexpress.net/mot-nhan-vien-cong-ty-di...
# 110         110  https://vnexpress.net/dia-oc-alibaba-phan-lo-t...
# 111         111  https://vnexpress.net/chu-tich-hdqt-cong-ty-di...
#
#                                                  title  \
# 0                     Quảng Ngãi có tân Bí thư Tỉnh ủy
# ...

# %% [markdown]
# ## Đếm tần suất xuất hiện của các chuyên mục

# %%
df['category'].value_counts()
# Out:
# Pháp luật           26
# Video               24
# Thời sự             15
# Thế giới            12
# Hồ sơ phá án     10
# THPT                 4
# Giáo dục             4
# Cuộc sống đó đây     3
# Tư vấn               2
# Học tiếng Anh        1
# Tin tức              1
# Giao thông           1
# Quân sự              1
# Tư liệu              1
# Name: category, dtype: int64

# %% [markdown]
# ## Lấy tất cả các bài báo có chuyên mục Thời sự

# %%
news_category = df.groupby('category')

# %%
news_category.get_group('Thời sự')
# Out:
#      Unnamed: 0                                               link  \
# 0             0  https://vnexpress.net/quang-ngai-co-tan-bi-thu...
# 4             4  https://vnexpress.net/container-tong-xe-5-cho-...
# 6             6  https://vnexpress.net/da-nang-tang-toc-xet-ngh...
# 7             7  https://vnexpress.net/chong-benh-nhan-o-dong-n...
# 9             9  https://vnexpress.net/ba-nguoi-trong-mot-gia-d...
# 10           10  https://vnexpress.net/thu-tuong-can-nhac-pham-...
# 28           28  https://vnexpress.net/ngan-chan-hon-16-000-ngu...
# 32           32  https://vnexpress.net/hang-chuc-nguoi-nhap-can...
# 36           36  https://vnexpress.net/lich-trinh-nam-benh-nhan...
# 39           39  https://vnexpress.net/quang-nam-cach-ly-xa-hoi...
# 62           62  https://vnexpress.net/nguoi-tu-da-nang-den-thu...
# 63           63  https://vnexpress.net/dau-tu-hon-12-ty-dong-xa...
# 64           64  https://vnexpress.net/noi-nguoi-dan-duoc-xay-c...
# ...
